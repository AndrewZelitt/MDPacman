# %% [markdown]
# In order to run our code you need the PYGAME library and the pygame_widgets library.
#
# In order to add these libraries, please go to your terminal and do :
#
# pip install pygame
#
# and
#
# pip install pygame_widgets

# %% [markdown]
# If you wish to run our code with the formal methods kernel, please run the below code block after the kernel is set to the formal methods kernel.

# %%
# %pip install pygame
# %pip install pygame_widgets

# %% [markdown]
# When using VSCode, in order to set the python interpreter for normal python files to the formal methods kernel,
#
# in the top search bar, type >Python: Select Interpreter
# and select the formal-methods interpreter, this code can run with the base python interpreter but if you wanted to, you could do it this way too.
